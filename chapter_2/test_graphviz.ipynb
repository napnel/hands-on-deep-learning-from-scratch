# %%
import networkx as nx
import matplotlib.pyplot as plt

# %%
from graphviz import Digraph

g = Digraph('G', filename='hello.gv')

g.edge('Hello', 'World')

g

# %%
g = Digraph(format='png')

for i in range(3):
    g.node(str(i), label='state{0}'.format(i+1))

edges = [[0, 0], [0, 1], [1, 0], [1, 2], [2, 0]]
edge_labels = ['0.5', '0.5', '0.3', '0.7', '1.0']

for i, e in enumerate(edges):
    g.edge(str(e[0]), str(e[1]), label=edge_labels[i])

g

# %%
g = Digraph()

g.node('x1')
g.node('x2')
g.node('y')

g.edge('x1', 'y', label='w1')
g.edge('x2', 'y', label='w2')
g

# %%
from graphviz import Graph

# g = Graph('G', filename='process.gv', engine='sfdp')
g = Graph('G', filename='process.gv', engine='neato')

g.edge('run', 'intr')
g.edge('intr', 'runbl')
g.edge('runbl', 'run')
g.edge('run', 'kernel')
g.edge('kernel', 'zombie')
g.edge('kernel', 'sleep')
g.edge('kernel', 'runmem')
g.edge('sleep', 'swap')
g.edge('swap', 'runswap')
g.edge('runswap', 'new')
g.edge('runswap', 'runmem')
g.edge('new', 'runmem')
g.edge('sleep', 'runmem')

g
